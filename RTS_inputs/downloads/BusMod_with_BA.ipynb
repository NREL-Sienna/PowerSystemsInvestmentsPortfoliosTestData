# %%
import pandas as pd

df_bus_mod = pd.read_csv('C:\\Users\\akarmaka\\Documents\\GitHub\\RTS-GMLC-master\\RTS-GMLC-master\\RTS_Data\\SourceData\\bus_mod.csv', header=0)#, usecols=['STNAME','CTYNAME','POPESTIMATE2021','STATE','COUNTY'])
df_heirarchy_nodal = pd.read_csv('C:\\Users\\akarmaka\\Documents\\GitHub\\ReEDS-2.0\\inputs\\hierarchy_rts_nodal.csv', header = 0)

df_bus_mod.columns = df_bus_mod.columns.str.replace(' ', '_')
df_bus_mod['Bus_ID'] = df_bus_mod['Bus_ID'].astype(str)
df_bus_mod['reeds_nodal'] = "b" + df_bus_mod['Bus_ID']

# %%
df_new_bus_mod = pd.merge(df_bus_mod, df_heirarchy_nodal, left_on='reeds_nodal', right_on='*Nodal', how='inner')

df_new_bus_mod
# Out:
#    Bus_ID  Bus_Name  BaseKV Bus_Type  MW_Load  MVAR_Load    V_Mag   V_Angle  \
# 0     101      Abel     138       PV      108         22  1.04777  -7.74152
# 1     102     Adams     138       PV       97         20  1.04783  -7.81784
# 2     103     Adler     138       PQ      180         37  1.01085  -7.21090
# 3     104  Agricola     138       PQ       74         15  1.01765 -10.56614
# 4     105     Aiken     138       PQ       71         14  1.03568 -10.70887
# ..    ...       ...     ...      ...      ...        ...      ...       ...
# 68    321      Cobb     230       PV        0          0  1.05000  12.34122
# 69    322      Cole     230       PV        0          0  1.05000  18.06914
# 70    323     Comte     230       PV        0          0  1.05000   8.62112
# 71    324     Curie     230       PQ        0          0  1.01046   1.30606
# 72    325   Curtiss     230       PQ        0          0  1.04986   8.99332
#
#     MW_Shunt_G  MVAR_Shunt_B  ...    FIPS   BA      nercr     transreg  st_y  \
# 0            0             0  ...  p04012  p28  WECC_SRSG  WestConnect    AZ
# 1            0             0  ...  p04027  p28  WECC_SRSG  WestConnect    AZ
# 2            0             0  ...  p06065  p10    WECC_CA        CAISO    CA
# 3            0             0  ...  p04012  p28  WECC_SRSG  WestConnect    AZ
# 4            0             0  ...  p04012  p28  WECC_SRSG  WestConnect    AZ
# ..         ...           ...  ...     ...  ...        ...          ...   ...
# 68           0             0  ...  p06071  p10    WECC_CA        CAISO    CA
# 69           0             0  ...  p06071  p10    WECC_CA        CAISO    CA
# 70           0             0  ...  p06071  p10    WECC_CA        CAISO    CA
# 71           0             0  ...  p06029  p10    WECC_CA        CAISO    CA
# 72           0             0  ...  p06071  p10    WECC_CA        CAISO    CA
#
#    interconnect country      usda      aggreg   county_name_y
# 0       western     USA  mountain          AZ          La Paz
# 1       western     USA  mountain          AZ            Yuma
# 2       western     USA   pacific  CA_S_CAISO       Riverside
# 3       western     USA  mountain          AZ          La Paz
# 4       western     USA  mountain          AZ          La Paz
# ..          ...     ...       ...         ...             ...
# 68      western     USA   pacific  CA_S_CAISO  San Bernardino
# 69      western     USA   pacific  CA_S_CAISO  San Bernardino
# 70      western     USA   pacific  CA_S_CAISO  San Bernardino
# 71      western     USA   pacific  CA_S_CAISO            Kern
# 72      western     USA   pacific  CA_S_CAISO  San Bernardino
#
# [73 rows x 29 columns]

# %%
df_new_bus_mod.drop(['nercr', 'transreg', 'st_y', 'interconnect', 'country', 'usda', 'aggreg'], axis=1, inplace=True)

df_new_bus_mod
# Out:
#    Bus_ID  Bus_Name  BaseKV Bus_Type  MW_Load  MVAR_Load    V_Mag   V_Angle  \
# 0     101      Abel     138       PV      108         22  1.04777  -7.74152
# 1     102     Adams     138       PV       97         20  1.04783  -7.81784
# 2     103     Adler     138       PQ      180         37  1.01085  -7.21090
# 3     104  Agricola     138       PQ       74         15  1.01765 -10.56614
# 4     105     Aiken     138       PQ       71         14  1.03568 -10.70887
# ..    ...       ...     ...      ...      ...        ...      ...       ...
# 68    321      Cobb     230       PV        0          0  1.05000  12.34122
# 69    322      Cole     230       PV        0          0  1.05000  18.06914
# 70    323     Comte     230       PV        0          0  1.05000   8.62112
# 71    324     Curie     230       PQ        0          0  1.01046   1.30606
# 72    325   Curtiss     230       PQ        0          0  1.04986   8.99332
#
#     MW_Shunt_G  MVAR_Shunt_B  ...  Zone        lat         lng  \
# 0            0             0  ...    11  33.396103 -113.835642
# 1            0             0  ...    12  33.357678 -113.825934
# 2            0             0  ...    11  33.536833 -114.670399
# 3            0             0  ...    11  33.812304 -113.825419
# 4            0             0  ...    11  33.659560 -113.999023
# ..         ...           ...  ...   ...        ...         ...
# 68           0             0  ...    37  35.745344 -117.115363
# 69           0             0  ...    37  36.438958 -117.485272
# 70           0             0  ...    35  34.253003 -117.113221
# 71           0             0  ...    36  35.206582 -118.034817
# 72           0             0  ...    35  34.251891 -117.128977
#
#                    county_name_x        st_x reeds_nodal *Nodal    FIPS   BA  \
# 0                  La Paz County     Arizona        b101   b101  p04012  p28
# 1                    Yuma County     Arizona        b102   b102  p04027  p28
# 2               Riverside County  California        b103   b103  p06065  p10
# 3                  La Paz County     Arizona        b104   b104  p04012  p28
# 4                  La Paz County     Arizona        b105   b105  p04012  p28
# ..                           ...         ...         ...    ...     ...  ...
# 68         San Bernardino County  California        b321   b321  p06071  p10
# 69  CAL Fire San Bernardino Unit  California        b322   b322  p06071  p10
# 70         San Bernardino County  California        b323   b323  p06071  p10
# 71                   Kern County  California        b324   b324  p06029  p10
# 72         San Bernardino County  California        b325   b325  p06071  p10
#
#      county_name_y
# 0           La Paz
# 1             Yuma
# 2        Riverside
# 3           La Paz
# 4           La Paz
# ..             ...
# 68  San Bernardino
# 69  San Bernardino
# 70  San Bernardino
# 71            Kern
# 72  San Bernardino
#
# [73 rows x 22 columns]

# %%
df_new_bus_mod.drop(['county_name_y', '*Nodal'], axis=1, inplace=True)

df_new_bus_mod
# Out:
#    Bus_ID  Bus_Name  BaseKV Bus_Type  MW_Load  MVAR_Load    V_Mag   V_Angle  \
# 0     101      Abel     138       PV      108         22  1.04777  -7.74152
# 1     102     Adams     138       PV       97         20  1.04783  -7.81784
# 2     103     Adler     138       PQ      180         37  1.01085  -7.21090
# 3     104  Agricola     138       PQ       74         15  1.01765 -10.56614
# 4     105     Aiken     138       PQ       71         14  1.03568 -10.70887
# ..    ...       ...     ...      ...      ...        ...      ...       ...
# 68    321      Cobb     230       PV        0          0  1.05000  12.34122
# 69    322      Cole     230       PV        0          0  1.05000  18.06914
# 70    323     Comte     230       PV        0          0  1.05000   8.62112
# 71    324     Curie     230       PQ        0          0  1.01046   1.30606
# 72    325   Curtiss     230       PQ        0          0  1.04986   8.99332
#
#     MW_Shunt_G  MVAR_Shunt_B  Area  Sub_Area  Zone        lat         lng  \
# 0            0             0     1        11    11  33.396103 -113.835642
# 1            0             0     1        11    12  33.357678 -113.825934
# 2            0             0     1        11    11  33.536833 -114.670399
# 3            0             0     1        11    11  33.812304 -113.825419
# 4            0             0     1        11    11  33.659560 -113.999023
# ..         ...           ...   ...       ...   ...        ...         ...
# 68           0             0     3        32    37  35.745344 -117.115363
# 69           0             0     3        32    37  36.438958 -117.485272
# 70           0             0     3        32    35  34.253003 -117.113221
# 71           0             0     3        32    36  35.206582 -118.034817
# 72           0             0     3        32    35  34.251891 -117.128977
#
#                    county_name_x        st_x reeds_nodal    FIPS   BA
# 0                  La Paz County     Arizona        b101  p04012  p28
# 1                    Yuma County     Arizona        b102  p04027  p28
# 2               Riverside County  California        b103  p06065  p10
# 3                  La Paz County     Arizona        b104  p04012  p28
# 4                  La Paz County     Arizona        b105  p04012  p28
# ..                           ...         ...         ...     ...  ...
# 68         San Bernardino County  California        b321  p06071  p10
# 69  CAL Fire San Bernardino Unit  California        b322  p06071  p10
# 70         San Bernardino County  California        b323  p06071  p10
# 71                   Kern County  California        b324  p06029  p10
# 72         San Bernardino County  California        b325  p06071  p10
#
# [73 rows x 20 columns]

# %%
df_new_bus_mod.rename(columns = {'st_x':'st', 'county_name_x':'county_name'}, inplace = True)
df_new_bus_mod
# Out:
#    Bus_ID  Bus_Name  BaseKV Bus_Type  MW_Load  MVAR_Load    V_Mag   V_Angle  \
# 0     101      Abel     138       PV      108         22  1.04777  -7.74152
# 1     102     Adams     138       PV       97         20  1.04783  -7.81784
# 2     103     Adler     138       PQ      180         37  1.01085  -7.21090
# 3     104  Agricola     138       PQ       74         15  1.01765 -10.56614
# 4     105     Aiken     138       PQ       71         14  1.03568 -10.70887
# ..    ...       ...     ...      ...      ...        ...      ...       ...
# 68    321      Cobb     230       PV        0          0  1.05000  12.34122
# 69    322      Cole     230       PV        0          0  1.05000  18.06914
# 70    323     Comte     230       PV        0          0  1.05000   8.62112
# 71    324     Curie     230       PQ        0          0  1.01046   1.30606
# 72    325   Curtiss     230       PQ        0          0  1.04986   8.99332
#
#     MW_Shunt_G  MVAR_Shunt_B  Area  Sub_Area  Zone        lat         lng  \
# 0            0             0     1        11    11  33.396103 -113.835642
# 1            0             0     1        11    12  33.357678 -113.825934
# 2            0             0     1        11    11  33.536833 -114.670399
# 3            0             0     1        11    11  33.812304 -113.825419
# 4            0             0     1        11    11  33.659560 -113.999023
# ..         ...           ...   ...       ...   ...        ...         ...
# 68           0             0     3        32    37  35.745344 -117.115363
# 69           0             0     3        32    37  36.438958 -117.485272
# 70           0             0     3        32    35  34.253003 -117.113221
# 71           0             0     3        32    36  35.206582 -118.034817
# 72           0             0     3        32    35  34.251891 -117.128977
#
#                      county_name          st reeds_nodal    FIPS   BA
# 0                  La Paz County     Arizona        b101  p04012  p28
# 1                    Yuma County     Arizona        b102  p04027  p28
# 2               Riverside County  California        b103  p06065  p10
# 3                  La Paz County     Arizona        b104  p04012  p28
# 4                  La Paz County     Arizona        b105  p04012  p28
# ..                           ...         ...         ...     ...  ...
# 68         San Bernardino County  California        b321  p06071  p10
# 69  CAL Fire San Bernardino Unit  California        b322  p06071  p10
# 70         San Bernardino County  California        b323  p06071  p10
# 71                   Kern County  California        b324  p06029  p10
# 72         San Bernardino County  California        b325  p06071  p10
#
# [73 rows x 20 columns]

# %%
df_new_bus_mod.to_csv('C:\\Users\\akarmaka\\Documents\\GitHub\\ReEDS-2.0\\RTS_Data\\SourceData\\bus_mod_updatedwithBA.csv', sep=',', encoding='utf-8', index=False)
