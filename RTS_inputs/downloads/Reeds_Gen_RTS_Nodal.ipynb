# %%
import pandas as pd

df_nodal_hierarchy = pd.read_csv('C:\\Users\\akarmaka\\Documents\\GitHub\\ReEDS-2.0\\inputs\\hierarchy_rts_nodal.csv', header=0)

df_reeds_gens = pd.read_csv('C:\\Users\\akarmaka\\Documents\\GitHub\\ReEDS-2.0\\inputs\\capacitydata\\ReEDS_generator_database_final_RTS-GMLC_withRTPV.csv', header=0)

df_reeds_gens
#df_p1_census = pd.read_csv('co-est2021-alldata.csv', header=0, usecols=['STNAME','CTYNAME','POPESTIMATE2021','STATE','COUNTY'], nrows=3195, encoding='latin-1')
#print(df_p1_census)

#df_p1_counties = pd.read_excel('county_reeds_corrected0310.xlsx', header=0, usecols=['NAME','STATE_NAME','FIPS','PCA_REG'])
#print(df_p1_counties)

#df_heirarchy_others = pd.read_csv('hierarchy_fips.csv', header = 0, usecols = ['FIPS','BA','nercr','transreg','cendiv','st', 'interconnect','country','usda','aggreg'])
#df_heirarchy_others = pd.read_csv('Reeds_SpatialFlex\\fprice\\hierarchy_bokeh.csv', header = 0) #, usecols = ['FIPS','BA','nercr','transreg','cendiv','st', 'interconnect','country','usda','aggreg'])

#df_heirarchy_others
# Out:
#            GEN UID  Bus ID  Gen ID Unit Group Unit Type        tech     Fuel  \
# 0         101_CT_1     101       1        U20        CT       o-g-s      Oil
# 1         101_CT_2     101       2        U20        CT       o-g-s      Oil
# 2      101_STEAM_3     101       3        U76     STEAM  coalolduns     Coal
# 3      101_STEAM_4     101       4        U76     STEAM  coalolduns     Coal
# 4         102_CT_1     102       1        U20        CT       o-g-s      Oil
# ..             ...     ...     ...        ...       ...         ...      ...
# 150     309_WIND_1     309       1       WIND      WIND    wind-ons     Wind
# 151     317_WIND_1     317       1       WIND      WIND    wind-ons     Wind
# 152     303_WIND_1     303       1       WIND      WIND    wind-ons     Wind
# 153     122_WIND_1     122       1       WIND      WIND    wind-ons     Wind
# 154  313_STORAGE_1     313       1    STORAGE   STORAGE   battery_4  Storage
#
#      MW Inj  MVAR Inj  V Setpoint p.u.  ...  ctt  Nuke80RetireYear  StartYear  \
# 0       8.0      4.96           1.0468  ...    n              2050       2012
# 1       8.0      4.96           1.0468  ...    n              2050       2009
# 2      76.0      0.14           1.0468  ...    n              2050       2012
# 3      76.0      0.14           1.0468  ...    n              2050       2009
# 4       8.0      4.88           1.0467  ...    n              2050       2009
# ..      ...       ...              ...  ...  ...               ...        ...
# 150     0.0      0.00           1.0000  ...    n              2050       2012
# 151     0.0      0.00           1.0000  ...    n              2050       2009
# 152     0.0      0.00           1.0000  ...    n              2050       2009
# 153     0.0      0.00           1.0000  ...    n              2050       2009
# 154     0.0      0.00           1.0000  ...    n              2050       2012
#
#      IsExistUnit  wst  resource_region  TC_WIN  coolingwatertech  RetireYear  \
# 0           True  fsa              328    20.0       o-g-s_n_fsa        2042
# 1           True  fsa              328    20.0       o-g-s_n_fsa        2039
# 2           True  fsa              328    76.0  coalolduns_n_fsa        2042
# 3           True  fsa              328    76.0  coalolduns_n_fsa        2039
# 4           True  fsa              328    20.0       o-g-s_n_fsa        2039
# ..           ...  ...              ...     ...               ...         ...
# 150         True  fsa              342   148.3    wind-ons_n_fsa        2042
# 151         True  fsa              342   799.1    wind-ons_n_fsa        2039
# 152         True  fsa              342   847.0    wind-ons_n_fsa        2039
# 153         True  fsa              328   713.5    wind-ons_n_fsa        2039
# 154         True  fsa              342    50.0   battery_4_n_fsa        2042
#
#      sc_point_gid
# 0               0
# 1               1
# 2               2
# 3               3
# 4               4
# ..            ...
# 150           153
# 151           154
# 152           155
# 153           156
# 154           157
#
# [155 rows x 86 columns]

# %%
df_reeds_gens['Bus ID'] = df_reeds_gens['Bus ID'].astype(str)

df_reeds_gens['reeds_ba'] = "b" + df_reeds_gens['Bus ID']
df_reeds_gens
# Out:
#            GEN UID Bus ID  Gen ID Unit Group Unit Type        tech     Fuel  \
# 0         101_CT_1    101       1        U20        CT       o-g-s      Oil
# 1         101_CT_2    101       2        U20        CT       o-g-s      Oil
# 2      101_STEAM_3    101       3        U76     STEAM  coalolduns     Coal
# 3      101_STEAM_4    101       4        U76     STEAM  coalolduns     Coal
# 4         102_CT_1    102       1        U20        CT       o-g-s      Oil
# ..             ...    ...     ...        ...       ...         ...      ...
# 150     309_WIND_1    309       1       WIND      WIND    wind-ons     Wind
# 151     317_WIND_1    317       1       WIND      WIND    wind-ons     Wind
# 152     303_WIND_1    303       1       WIND      WIND    wind-ons     Wind
# 153     122_WIND_1    122       1       WIND      WIND    wind-ons     Wind
# 154  313_STORAGE_1    313       1    STORAGE   STORAGE   battery_4  Storage
#
#      MW Inj  MVAR Inj  V Setpoint p.u.  ...  ctt  Nuke80RetireYear  StartYear  \
# 0       8.0      4.96           1.0468  ...    n              2050       2012
# 1       8.0      4.96           1.0468  ...    n              2050       2009
# 2      76.0      0.14           1.0468  ...    n              2050       2012
# 3      76.0      0.14           1.0468  ...    n              2050       2009
# 4       8.0      4.88           1.0467  ...    n              2050       2009
# ..      ...       ...              ...  ...  ...               ...        ...
# 150     0.0      0.00           1.0000  ...    n              2050       2012
# 151     0.0      0.00           1.0000  ...    n              2050       2009
# 152     0.0      0.00           1.0000  ...    n              2050       2009
# 153     0.0      0.00           1.0000  ...    n              2050       2009
# 154     0.0      0.00           1.0000  ...    n              2050       2012
#
#      IsExistUnit  wst  resource_region  TC_WIN  coolingwatertech  RetireYear  \
# 0           True  fsa              328    20.0       o-g-s_n_fsa        2042
# 1           True  fsa              328    20.0       o-g-s_n_fsa        2039
# 2           True  fsa              328    76.0  coalolduns_n_fsa        2042
# 3           True  fsa              328    76.0  coalolduns_n_fsa        2039
# 4           True  fsa              328    20.0       o-g-s_n_fsa        2039
# ..           ...  ...              ...     ...               ...         ...
# 150         True  fsa              342   148.3    wind-ons_n_fsa        2042
# 151         True  fsa              342   799.1    wind-ons_n_fsa        2039
# 152         True  fsa              342   847.0    wind-ons_n_fsa        2039
# 153         True  fsa              328   713.5    wind-ons_n_fsa        2039
# 154         True  fsa              342    50.0   battery_4_n_fsa        2042
#
#      sc_point_gid
# 0               0
# 1               1
# 2               2
# 3               3
# 4               4
# ..            ...
# 150           153
# 151           154
# 152           155
# 153           156
# 154           157
#
# [155 rows x 86 columns]

# %%
#left_on = reeds_ba before switching column name; updated should be reeds_nodal
df_hierarchy_nodal_gens = pd.merge(df_reeds_gens, df_nodal_hierarchy, left_on=['reeds_ba'], right_on=['*Nodal'], how='inner')
df_hierarchy_nodal_gens
# Out:
#          GEN UID Bus ID  Gen ID Unit Group Unit Type        tech   Fuel  \
# 0       101_CT_1    101       1        U20        CT       o-g-s    Oil
# 1       101_CT_2    101       2        U20        CT       o-g-s    Oil
# 2    101_STEAM_3    101       3        U76     STEAM  coalolduns   Coal
# 3    101_STEAM_4    101       4        U76     STEAM  coalolduns   Coal
# 4       101_PV_1    101       1         PV        PV         upv  Solar
# ..           ...    ...     ...        ...       ...         ...    ...
# 150     119_PV_1    119       1         PV        PV         upv  Solar
# 151   308_RTPV_1    308       1       RTPV      RTPV      distpv  Solar
# 152   309_WIND_1    309       1       WIND      WIND    wind-ons   Wind
# 153   317_WIND_1    317       1       WIND      WIND    wind-ons   Wind
# 154   303_WIND_1    303       1       WIND      WIND    wind-ons   Wind
#
#      MW Inj  MVAR Inj  V Setpoint p.u.  ...    FIPS   BA      nercr  \
# 0       8.0      4.96           1.0468  ...  p04012  p28  WECC_SRSG
# 1       8.0      4.96           1.0468  ...  p04012  p28  WECC_SRSG
# 2      76.0      0.14           1.0468  ...  p04012  p28  WECC_SRSG
# 3      76.0      0.14           1.0468  ...  p04012  p28  WECC_SRSG
# 4       0.0      0.00           1.0000  ...  p04012  p28  WECC_SRSG
# ..      ...       ...              ...  ...     ...  ...        ...
# 150     0.0      0.00           1.0000  ...  p06065  p10    WECC_CA
# 151     0.0      0.00           1.0000  ...  p06037  p10    WECC_CA
# 152     0.0      0.00           1.0000  ...  p06037  p10    WECC_CA
# 153     0.0      0.00           1.0000  ...  p06071  p10    WECC_CA
# 154     0.0      0.00           1.0000  ...  p06029  p10    WECC_CA
#
#         transreg  st  interconnect  country      usda      aggreg  \
# 0    WestConnect  AZ       western      USA  mountain          AZ
# 1    WestConnect  AZ       western      USA  mountain          AZ
# 2    WestConnect  AZ       western      USA  mountain          AZ
# 3    WestConnect  AZ       western      USA  mountain          AZ
# 4    WestConnect  AZ       western      USA  mountain          AZ
# ..           ...  ..           ...      ...       ...         ...
# 150        CAISO  CA       western      USA   pacific  CA_S_CAISO
# 151        CAISO  CA       western      USA   pacific  CA_S_CAISO
# 152        CAISO  CA       western      USA   pacific  CA_S_CAISO
# 153        CAISO  CA       western      USA   pacific  CA_S_CAISO
# 154        CAISO  CA       western      USA   pacific  CA_S_CAISO
#
#         county_name
# 0            La Paz
# 1            La Paz
# 2            La Paz
# 3            La Paz
# 4            La Paz
# ..              ...
# 150       Riverside
# 151     Los Angeles
# 152     Los Angeles
# 153  San Bernardino
# 154            Kern
#
# [155 rows x 97 columns]

# %%
df_hierarchy_nodal_gens.drop(['*Nodal', 'FIPS', 'nercr', 'transreg','st', 'interconnect', 'country', 'usda', 'aggreg', 'county_name'], axis=1, inplace=True)
df_hierarchy_nodal_gens
# Out:
#          GEN UID Bus ID  Gen ID Unit Group Unit Type        tech   Fuel  \
# 0       101_CT_1    101       1        U20        CT       o-g-s    Oil
# 1       101_CT_2    101       2        U20        CT       o-g-s    Oil
# 2    101_STEAM_3    101       3        U76     STEAM  coalolduns   Coal
# 3    101_STEAM_4    101       4        U76     STEAM  coalolduns   Coal
# 4       101_PV_1    101       1         PV        PV         upv  Solar
# ..           ...    ...     ...        ...       ...         ...    ...
# 150     119_PV_1    119       1         PV        PV         upv  Solar
# 151   308_RTPV_1    308       1       RTPV      RTPV      distpv  Solar
# 152   309_WIND_1    309       1       WIND      WIND    wind-ons   Wind
# 153   317_WIND_1    317       1       WIND      WIND    wind-ons   Wind
# 154   303_WIND_1    303       1       WIND      WIND    wind-ons   Wind
#
#      MW Inj  MVAR Inj  V Setpoint p.u.  ...  Nuke80RetireYear  StartYear  \
# 0       8.0      4.96           1.0468  ...              2050       2012
# 1       8.0      4.96           1.0468  ...              2050       2009
# 2      76.0      0.14           1.0468  ...              2050       2012
# 3      76.0      0.14           1.0468  ...              2050       2009
# 4       0.0      0.00           1.0000  ...              2050       2009
# ..      ...       ...              ...  ...               ...        ...
# 150     0.0      0.00           1.0000  ...              2050       2009
# 151     0.0      0.00           1.0000  ...              2050       2012
# 152     0.0      0.00           1.0000  ...              2050       2012
# 153     0.0      0.00           1.0000  ...              2050       2009
# 154     0.0      0.00           1.0000  ...              2050       2009
#
#      IsExistUnit  wst  resource_region  TC_WIN  coolingwatertech  RetireYear  \
# 0           True  fsa              328    20.0       o-g-s_n_fsa        2042
# 1           True  fsa              328    20.0       o-g-s_n_fsa        2039
# 2           True  fsa              328    76.0  coalolduns_n_fsa        2042
# 3           True  fsa              328    76.0  coalolduns_n_fsa        2039
# 4           True  fsa              328    25.9         upv_n_fsa        2039
# ..           ...  ...              ...     ...               ...         ...
# 150         True  fsa              328    66.6         upv_n_fsa        2039
# 151         True  fsa              342   100.9      distpv_n_fsa        2042
# 152         True  fsa              342   148.3    wind-ons_n_fsa        2042
# 153         True  fsa              342   799.1    wind-ons_n_fsa        2039
# 154         True  fsa              342   847.0    wind-ons_n_fsa        2039
#
#      sc_point_gid   BA
# 0               0  p28
# 1               1  p28
# 2               2  p28
# 3               3  p28
# 4             113  p28
# ..            ...  ...
# 150           121  p10
# 151           122  p10
# 152           153  p10
# 153           154  p10
# 154           155  p10
#
# [155 rows x 87 columns]

# %%
df_hierarchy_nodal_gens.rename(columns = {'reeds_ba':'reeds_nodal', 'BA':'reeds_ba'}, inplace = True)
df_hierarchy_nodal_gens
# Out:
#          GEN UID Bus ID  Gen ID Unit Group Unit Type        tech   Fuel  \
# 0       101_CT_1    101       1        U20        CT       o-g-s    Oil
# 1       101_CT_2    101       2        U20        CT       o-g-s    Oil
# 2    101_STEAM_3    101       3        U76     STEAM  coalolduns   Coal
# 3    101_STEAM_4    101       4        U76     STEAM  coalolduns   Coal
# 4       101_PV_1    101       1         PV        PV         upv  Solar
# ..           ...    ...     ...        ...       ...         ...    ...
# 150     119_PV_1    119       1         PV        PV         upv  Solar
# 151   308_RTPV_1    308       1       RTPV      RTPV      distpv  Solar
# 152   309_WIND_1    309       1       WIND      WIND    wind-ons   Wind
# 153   317_WIND_1    317       1       WIND      WIND    wind-ons   Wind
# 154   303_WIND_1    303       1       WIND      WIND    wind-ons   Wind
#
#      MW Inj  MVAR Inj  V Setpoint p.u.  ...  Nuke80RetireYear  StartYear  \
# 0       8.0      4.96           1.0468  ...              2050       2012
# 1       8.0      4.96           1.0468  ...              2050       2009
# 2      76.0      0.14           1.0468  ...              2050       2012
# 3      76.0      0.14           1.0468  ...              2050       2009
# 4       0.0      0.00           1.0000  ...              2050       2009
# ..      ...       ...              ...  ...               ...        ...
# 150     0.0      0.00           1.0000  ...              2050       2009
# 151     0.0      0.00           1.0000  ...              2050       2012
# 152     0.0      0.00           1.0000  ...              2050       2012
# 153     0.0      0.00           1.0000  ...              2050       2009
# 154     0.0      0.00           1.0000  ...              2050       2009
#
#      IsExistUnit  wst  resource_region  TC_WIN  coolingwatertech  RetireYear  \
# 0           True  fsa              328    20.0       o-g-s_n_fsa        2042
# 1           True  fsa              328    20.0       o-g-s_n_fsa        2039
# 2           True  fsa              328    76.0  coalolduns_n_fsa        2042
# 3           True  fsa              328    76.0  coalolduns_n_fsa        2039
# 4           True  fsa              328    25.9         upv_n_fsa        2039
# ..           ...  ...              ...     ...               ...         ...
# 150         True  fsa              328    66.6         upv_n_fsa        2039
# 151         True  fsa              342   100.9      distpv_n_fsa        2042
# 152         True  fsa              342   148.3    wind-ons_n_fsa        2042
# 153         True  fsa              342   799.1    wind-ons_n_fsa        2039
# 154         True  fsa              342   847.0    wind-ons_n_fsa        2039
#
#      sc_point_gid  reeds_ba
# 0               0       p28
# 1               1       p28
# 2               2       p28
# 3               3       p28
# 4             113       p28
# ..            ...       ...
# 150           121       p10
# 151           122       p10
# 152           153       p10
# 153           154       p10
# 154           155       p10
#
# [155 rows x 87 columns]

# %%
# Write dataframe to csv file (UNCOMPRESSED)
df_hierarchy_nodal_gens.to_csv('C:\\Users\\akarmaka\\Documents\\GitHub\\ReEDS-2.0\\inputs\\capacitydata\\ReEDS_generator_database_final_RTS-GMLC_updated_nodal.csv', sep=',', encoding='utf-8', index=False)
