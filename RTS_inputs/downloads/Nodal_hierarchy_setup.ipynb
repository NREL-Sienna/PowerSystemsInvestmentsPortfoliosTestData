# %%
import csv
from geopy.geocoders import Nominatim

def county_locator(latitude, longitude):
    geolocator = Nominatim(user_agent="county-lookup")
    location = geolocator.reverse((latitude, longitude), exactly_one=True)
    address = location.raw['address']
    county_name = address.get('county', None)
    state_name = address.get('state', '')
    return county_name, state_name

#def main():
bus_file_csv = "C:\\Users\\akarmaka\\Documents\\GitHub\\RTS-GMLC-master\\RTS-GMLC-master\\RTS_Data\\SourceData\\bus.csv"
mod_bus_file = "C:\\Users\\akarmaka\\Documents\\GitHub\\RTS-GMLC-master\\RTS-GMLC-master\\RTS_Data\\SourceData\\bus_mod.csv"
with open(bus_file_csv, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames
    fieldnames += ['county_name', 'st']
    with open(mod_bus_file, 'w', newline='') as output_file:
        writer = csv.DictWriter(output_file, fieldnames=fieldnames)
        writer.writeheader()
        for row in reader:
            latitude = float(row['lat'])
            longitude = float(row['lng'])
            
            county_name, state_name = county_locator(latitude, longitude)
            
            row['county_name'] = county_name
            row['st'] = state_name
            
            writer.writerow(row)
            
            #print(f"Lat: {latitude}, longitude: {longitude}, County FIPS: {county_name}, State: {state_name}")
        
print("Bus file now has county names and state names!")
# Out:
# Bus file now has county names and state names!

# %%
import pandas as pd

df_bus_mod = pd.read_csv('C:\\Users\\akarmaka\\Documents\\GitHub\\RTS-GMLC-master\\RTS-GMLC-master\\RTS_Data\\SourceData\\bus_mod.csv', header=0)#, usecols=['STNAME','CTYNAME','POPESTIMATE2021','STATE','COUNTY'])

df_p1_census = pd.read_csv('co-est2021-alldata.csv', header=0, usecols=['STNAME','CTYNAME','POPESTIMATE2021','STATE','COUNTY'], nrows=3195, encoding='latin-1')
#print(df_p1_census)

df_p1_counties = pd.read_excel('county_reeds_corrected0310.xlsx', header=0, usecols=['NAME','STATE_NAME','FIPS','PCA_REG'])
#print(df_p1_counties)

df_heirarchy_others = pd.read_csv('hierarchy_fips.csv', header = 0, usecols = ['FIPS','BA','nercr','transreg','cendiv','st', 'interconnect','country','usda','aggreg'])
#df_heirarchy_others = pd.read_csv('Reeds_SpatialFlex\\fprice\\hierarchy_bokeh.csv', header = 0) #, usecols = ['FIPS','BA','nercr','transreg','cendiv','st', 'interconnect','country','usda','aggreg'])

df_heirarchy_others
# Out:
#        FIPS    BA      nercr      transreg cendiv  st interconnect country  \
# 0     53007    p1  WECC_NWPP  NorthernGrid     PA  WA      western     USA
# 1     53029    p1  WECC_NWPP  NorthernGrid     PA  WA      western     USA
# 2     53033    p1  WECC_NWPP  NorthernGrid     PA  WA      western     USA
# 3     53035    p1  WECC_NWPP  NorthernGrid     PA  WA      western     USA
# 4     53037    p1  WECC_NWPP  NorthernGrid     PA  WA      western     USA
# ...     ...   ...        ...           ...    ...  ..          ...     ...
# 3102  23023  p134    NPCC_NE         ISONE     NE  ME      eastern     USA
# 3103  23025  p134    NPCC_NE         ISONE     NE  ME      eastern     USA
# 3104  23027  p134    NPCC_NE         ISONE     NE  ME      eastern     USA
# 3105  23029  p134    NPCC_NE         ISONE     NE  ME      eastern     USA
# 3106  23031  p134    NPCC_NE         ISONE     NE  ME      eastern     USA
#
#            usda aggreg
# 0       pacific     WA
# 1       pacific     WA
# 2       pacific     WA
# 3       pacific     WA
# 4       pacific     WA
# ...         ...    ...
# 3102  northeast     ME
# 3103  northeast     ME
# 3104  northeast     ME
# 3105  northeast     ME
# 3106  northeast     ME
#
# [3107 rows x 10 columns]

# %%
df_bus_mod['county_name'] = df_bus_mod['county_name'].str.replace(' County', '')
df_bus_mod['county_name'] = df_bus_mod['county_name'].str.replace('CAL Fire ', '')
df_bus_mod['county_name'] = df_bus_mod['county_name'].str.replace(' Unit', '')
#df_bus_mod.rename(columns = {'Bus ID':'Bus_ID', 'Bus Name':'Bus_Name', 'Bus Type': 'Bus_Type', 'MW Load': 'MW_Load', 'MVAR Load': 'MVAR Load'}, inplace = True)
df_bus_mod.columns = df_bus_mod.columns.str.replace(' ', '_')
df_bus_mod
# Out:
#     Bus_ID  Bus_Name  BaseKV Bus_Type  MW_Load  MVAR_Load    V_Mag   V_Angle  \
# 0      101      Abel     138       PV      108         22  1.04777  -7.74152
# 1      102     Adams     138       PV       97         20  1.04783  -7.81784
# 2      103     Adler     138       PQ      180         37  1.01085  -7.21090
# 3      104  Agricola     138       PQ       74         15  1.01765 -10.56614
# 4      105     Aiken     138       PQ       71         14  1.03568 -10.70887
# ..     ...       ...     ...      ...      ...        ...      ...       ...
# 68     321      Cobb     230       PV        0          0  1.05000  12.34122
# 69     322      Cole     230       PV        0          0  1.05000  18.06914
# 70     323     Comte     230       PV        0          0  1.05000   8.62112
# 71     324     Curie     230       PQ        0          0  1.01046   1.30606
# 72     325   Curtiss     230       PQ        0          0  1.04986   8.99332
#
#     MW_Shunt_G  MVAR_Shunt_B  Area  Sub_Area  Zone        lat         lng  \
# 0            0             0     1        11    11  33.396103 -113.835642
# 1            0             0     1        11    12  33.357678 -113.825934
# 2            0             0     1        11    11  33.536833 -114.670399
# 3            0             0     1        11    11  33.812304 -113.825419
# 4            0             0     1        11    11  33.659560 -113.999023
# ..         ...           ...   ...       ...   ...        ...         ...
# 68           0             0     3        32    37  35.745344 -117.115363
# 69           0             0     3        32    37  36.438958 -117.485272
# 70           0             0     3        32    35  34.253003 -117.113221
# 71           0             0     3        32    36  35.206582 -118.034817
# 72           0             0     3        32    35  34.251891 -117.128977
#
#        county_name          st
# 0           La Paz     Arizona
# 1             Yuma     Arizona
# 2        Riverside  California
# 3           La Paz     Arizona
# 4           La Paz     Arizona
# ..             ...         ...
# 68  San Bernardino  California
# 69  San Bernardino  California
# 70  San Bernardino  California
# 71            Kern  California
# 72  San Bernardino  California
#
# [73 rows x 17 columns]

# %%
df_bus_mod.dtypes
# Out:
# Bus_ID            int64
# Bus_Name         object
# BaseKV            int64
# Bus_Type         object
# MW_Load           int64
# MVAR_Load         int64
# V_Mag           float64
# V_Angle         float64
# MW_Shunt_G        int64
# MVAR_Shunt_B      int64
# Area              int64
# Sub_Area          int64
# Zone              int64
# lat             float64
# lng             float64
# county_name      object
# st               object
# dtype: object

# %%
#df_bus_mod = df_bus_mod.insert(17,'Nodal_Zone', 0)
df_bus_mod['Bus_ID'] = df_bus_mod['Bus_ID'].astype(str)

df_bus_mod['Nodal'] = "b" + df_bus_mod['Bus_ID']
df_bus_mod
# Out:
#    Bus_ID  Bus_Name  BaseKV Bus_Type  MW_Load  MVAR_Load    V_Mag   V_Angle  \
# 0     101      Abel     138       PV      108         22  1.04777  -7.74152
# 1     102     Adams     138       PV       97         20  1.04783  -7.81784
# 2     103     Adler     138       PQ      180         37  1.01085  -7.21090
# 3     104  Agricola     138       PQ       74         15  1.01765 -10.56614
# 4     105     Aiken     138       PQ       71         14  1.03568 -10.70887
# ..    ...       ...     ...      ...      ...        ...      ...       ...
# 68    321      Cobb     230       PV        0          0  1.05000  12.34122
# 69    322      Cole     230       PV        0          0  1.05000  18.06914
# 70    323     Comte     230       PV        0          0  1.05000   8.62112
# 71    324     Curie     230       PQ        0          0  1.01046   1.30606
# 72    325   Curtiss     230       PQ        0          0  1.04986   8.99332
#
#     MW_Shunt_G  MVAR_Shunt_B  Area  Sub_Area  Zone        lat         lng  \
# 0            0             0     1        11    11  33.396103 -113.835642
# 1            0             0     1        11    12  33.357678 -113.825934
# 2            0             0     1        11    11  33.536833 -114.670399
# 3            0             0     1        11    11  33.812304 -113.825419
# 4            0             0     1        11    11  33.659560 -113.999023
# ..         ...           ...   ...       ...   ...        ...         ...
# 68           0             0     3        32    37  35.745344 -117.115363
# 69           0             0     3        32    37  36.438958 -117.485272
# 70           0             0     3        32    35  34.253003 -117.113221
# 71           0             0     3        32    36  35.206582 -118.034817
# 72           0             0     3        32    35  34.251891 -117.128977
#
#        county_name          st Nodal_Zone
# 0           La Paz     Arizona       b101
# 1             Yuma     Arizona       b102
# 2        Riverside  California       b103
# 3           La Paz     Arizona       b104
# 4           La Paz     Arizona       b105
# ..             ...         ...        ...
# 68  San Bernardino  California       b321
# 69  San Bernardino  California       b322
# 70  San Bernardino  California       b323
# 71            Kern  California       b324
# 72  San Bernardino  California       b325
#
# [73 rows x 18 columns]

# %%
df_p1_counties['FIPS']=df_p1_counties['FIPS'].apply(lambda x: '{0:0>5}'.format(x))
df_p1_counties
# Out:
#             NAME STATE_NAME   FIPS  PCA_REG
# 0        Autauga    Alabama  01001       90
# 1        Baldwin    Alabama  01003       90
# 2        Barbour    Alabama  01005       90
# 3           Bibb    Alabama  01007       89
# 4         Blount    Alabama  01009       90
# ...          ...        ...    ...      ...
# 3104  Sweetwater    Wyoming  56037       21
# 3105       Teton    Wyoming  56039       21
# 3106       Uinta    Wyoming  56041       21
# 3107    Washakie    Wyoming  56043       21
# 3108      Weston    Wyoming  56045       23
#
# [3109 rows x 4 columns]

# %%
df_p1_counties['FIPS'] = df_p1_counties['FIPS'].astype('int64')
df_p1_counties
# Out:
#             NAME STATE_NAME   FIPS  PCA_REG
# 0        Autauga    Alabama   1001       90
# 1        Baldwin    Alabama   1003       90
# 2        Barbour    Alabama   1005       90
# 3           Bibb    Alabama   1007       89
# 4         Blount    Alabama   1009       90
# ...          ...        ...    ...      ...
# 3104  Sweetwater    Wyoming  56037       21
# 3105       Teton    Wyoming  56039       21
# 3106       Uinta    Wyoming  56041       21
# 3107    Washakie    Wyoming  56043       21
# 3108      Weston    Wyoming  56045       23
#
# [3109 rows x 4 columns]

# %%
df_heirarchy_counties = pd.merge(df_heirarchy_others, df_p1_counties, on='FIPS', how='right')
#df_heirarchy_counties = pd.merge(df_heirarchy_others, df_p1_counties, left_on='rb', right_on='PCA_REG', how='inner')
df_heirarchy_counties
# Out:
#        FIPS   BA      nercr      transreg cendiv  st interconnect country  \
# 0      1001  p90       SERC         SERTP    ESC  AL      eastern     USA
# 1      1003  p90       SERC         SERTP    ESC  AL      eastern     USA
# 2      1005  p90       SERC         SERTP    ESC  AL      eastern     USA
# 3      1007  p89       SERC         SERTP    ESC  AL      eastern     USA
# 4      1009  p90       SERC         SERTP    ESC  AL      eastern     USA
# ...     ...  ...        ...           ...    ...  ..          ...     ...
# 3104  56037  p21  WECC_NWPP  NorthernGrid    MTN  WY      western     USA
# 3105  56039  p21  WECC_NWPP  NorthernGrid    MTN  WY      western     USA
# 3106  56041  p21  WECC_NWPP  NorthernGrid    MTN  WY      western     USA
# 3107  56043  p21  WECC_NWPP  NorthernGrid    MTN  WY      western     USA
# 3108  56045  p23  WECC_NWPP   WestConnect    MTN  WY      western     USA
#
#            usda           aggreg        NAME STATE_NAME  PCA_REG
# 0     southeast               AL     Autauga    Alabama       90
# 1     southeast               AL     Baldwin    Alabama       90
# 2     southeast               AL     Barbour    Alabama       90
# 3     southeast               AL        Bibb    Alabama       89
# 4     southeast               AL      Blount    Alabama       90
# ...         ...              ...         ...        ...      ...
# 3104   mountain  WY_NorthernGrid  Sweetwater    Wyoming       21
# 3105   mountain  WY_NorthernGrid       Teton    Wyoming       21
# 3106   mountain  WY_NorthernGrid       Uinta    Wyoming       21
# 3107   mountain  WY_NorthernGrid    Washakie    Wyoming       21
# 3108   mountain   WY_WestConnect      Weston    Wyoming       23
#
# [3109 rows x 13 columns]

# %%
df_hierarchy_nodal_add = pd.merge(df_heirarchy_counties, df_bus_mod, left_on=['NAME', 'STATE_NAME'], right_on=['county_name', 'st'], how='inner')
df_hierarchy_nodal_add
# Out:
#      FIPS   BA      nercr      transreg cendiv st_x interconnect country  \
# 0    4005  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 1    4005  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 2    4012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 3    4012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 4    4012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# ..    ...  ...        ...           ...    ...  ...          ...     ...
# 68  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 69  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 70  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 71  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 72  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
#
#         usda aggreg  ... MW_Shunt_G MVAR_Shunt_B  Area Sub_Area Zone  \
# 0   mountain     AZ  ...          0            0     2       21   22
# 1   mountain     AZ  ...          0            0     2       21   22
# 2   mountain     AZ  ...          0            0     1       11   11
# 3   mountain     AZ  ...          0            0     1       11   11
# 4   mountain     AZ  ...          0            0     1       11   11
# ..       ...    ...  ...        ...          ...   ...      ...  ...
# 68  mountain     NV  ...          0            0     2       22   26
# 69  mountain     NV  ...          0            0     2       22   26
# 70  mountain     NV  ...          0            0     2       22   25
# 71  mountain     NV  ...          0            0     2       22   27
# 72  mountain     NV  ...          0            0     2       22   25
#
#           lat         lng  county_name     st_y  Nodal_Zone
# 0   36.052467 -113.082849     Coconino  Arizona        b207
# 1   35.933814 -113.317701     Coconino  Arizona        b208
# 2   33.396103 -113.835642       La Paz  Arizona        b101
# 3   33.812304 -113.825419       La Paz  Arizona        b104
# 4   33.659560 -113.999023       La Paz  Arizona        b105
# ..        ...         ...          ...      ...         ...
# 68  35.148591 -114.575774        Clark   Nevada        b215
# 69  35.261490 -114.730763        Clark   Nevada        b216
# 70  35.419217 -114.979182        Clark   Nevada        b219
# 71  36.330981 -115.290210        Clark   Nevada        b222
# 72  35.824350 -115.536446        Clark   Nevada        b223
#
# [73 rows x 31 columns]

# %%
df_hierarchy_nodal_add.drop(['Bus_Name','BaseKV','Bus_Type', 'MW_Load', 'MVAR_Load','V_Mag', 'V_Angle', 'MW_Shunt_G', 'MVAR_Shunt_B', 'Area', 'Zone', 'lat', 'lng', 'st_y', 'Bus_ID', 'Sub_Area', 'STATE_NAME','PCA_REG','NAME','STATE_NAME'], axis=1, inplace=True)
df_hierarchy_nodal_add
# Out:
#      FIPS   BA      nercr      transreg cendiv st_x interconnect country  \
# 0    4005  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 1    4005  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 2    4012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 3    4012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 4    4012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# ..    ...  ...        ...           ...    ...  ...          ...     ...
# 68  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 69  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 70  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 71  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 72  32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
#
#         usda aggreg county_name Nodal_Zone
# 0   mountain     AZ    Coconino       b207
# 1   mountain     AZ    Coconino       b208
# 2   mountain     AZ      La Paz       b101
# 3   mountain     AZ      La Paz       b104
# 4   mountain     AZ      La Paz       b105
# ..       ...    ...         ...        ...
# 68  mountain     NV       Clark       b215
# 69  mountain     NV       Clark       b216
# 70  mountain     NV       Clark       b219
# 71  mountain     NV       Clark       b222
# 72  mountain     NV       Clark       b223
#
# [73 rows x 12 columns]

# %%
df_hierarchy_nodal_add.rename(columns = {'st_x':'st'}, inplace = True)
df_hierarchy_nodal_add['FIPS']=df_hierarchy_nodal_add['FIPS'].apply(lambda x: '{0:0>5}'.format(x))
df_hierarchy_nodal_add.sample(20)
# Out:
#       FIPS   BA      nercr      transreg cendiv  st interconnect country  \
# 39  p06065  p10    WECC_CA         CAISO     PA  CA      western     USA
# 7   p04012  p28  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 68  p32003  p13  WECC_NWPP  NorthernGrid    MTN  NV      western     USA
# 54  p06071  p10    WECC_CA         CAISO     PA  CA      western     USA
# 22  p04015  p27  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 33  p06037  p10    WECC_CA         CAISO     PA  CA      western     USA
# 71  p32003  p13  WECC_NWPP  NorthernGrid    MTN  NV      western     USA
# 16  p04015  p27  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 44  p06065  p10    WECC_CA         CAISO     PA  CA      western     USA
# 32  p06037  p10    WECC_CA         CAISO     PA  CA      western     USA
# 48  p06071  p10    WECC_CA         CAISO     PA  CA      western     USA
# 25  p06029  p10    WECC_CA         CAISO     PA  CA      western     USA
# 14  p04015  p27  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 41  p06065  p10    WECC_CA         CAISO     PA  CA      western     USA
# 15  p04015  p27  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 28  p06029  p10    WECC_CA         CAISO     PA  CA      western     USA
# 65  p06073  p11    WECC_CA         CAISO     PA  CA      western     USA
# 31  p06037  p10    WECC_CA         CAISO     PA  CA      western     USA
# 24  p06029  p10    WECC_CA         CAISO     PA  CA      western     USA
# 26  p06029  p10    WECC_CA         CAISO     PA  CA      western     USA
#
#         usda      aggreg     county_name Nodal_Zone
# 39   pacific  CA_S_CAISO       Riverside       b103
# 7   mountain          AZ          La Paz       b110
# 68  mountain          NV           Clark       b215
# 54   pacific  CA_S_CAISO  San Bernardino       b221
# 22  mountain          AZ          Mohave       b224
# 33   pacific  CA_S_CAISO     Los Angeles       b308
# 71  mountain          NV           Clark       b222
# 16  mountain          AZ          Mohave       b206
# 44   pacific  CA_S_CAISO       Riverside       b118
# 32   pacific  CA_S_CAISO     Los Angeles       b307
# 48   pacific  CA_S_CAISO  San Bernardino       b113
# 25   pacific  CA_S_CAISO            Kern       b302
# 14  mountain          AZ          Mohave       b203
# 41   pacific  CA_S_CAISO       Riverside       b115
# 15  mountain          AZ          Mohave       b205
# 28   pacific  CA_S_CAISO            Kern       b306
# 65   pacific  CA_S_CAISO       San Diego       b122
# 31   pacific  CA_S_CAISO     Los Angeles       b304
# 24   pacific  CA_S_CAISO            Kern       b301
# 26   pacific  CA_S_CAISO            Kern       b303

# %%
df_hierarchy_nodal_add['FIPS'] = "p" + df_hierarchy_nodal_add['FIPS'].astype(str)
df_hierarchy_nodal_add
# Out:
#       FIPS   BA      nercr      transreg cendiv st_x interconnect country  \
# 0   p04005  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 1   p04005  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 2   p04012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 3   p04012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# 4   p04012  p28  WECC_SRSG   WestConnect    MTN   AZ      western     USA
# ..     ...  ...        ...           ...    ...  ...          ...     ...
# 68  p32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 69  p32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 70  p32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 71  p32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
# 72  p32003  p13  WECC_NWPP  NorthernGrid    MTN   NV      western     USA
#
#         usda aggreg county_name Nodal_Zone
# 0   mountain     AZ    Coconino       b207
# 1   mountain     AZ    Coconino       b208
# 2   mountain     AZ      La Paz       b101
# 3   mountain     AZ      La Paz       b104
# 4   mountain     AZ      La Paz       b105
# ..       ...    ...         ...        ...
# 68  mountain     NV       Clark       b215
# 69  mountain     NV       Clark       b216
# 70  mountain     NV       Clark       b219
# 71  mountain     NV       Clark       b222
# 72  mountain     NV       Clark       b223
#
# [73 rows x 12 columns]

# %%
len_check = df_hierarchy_nodal_add['FIPS'].str.len()==5
len_check
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 68    False
# 69    False
# 70    False
# 71    False
# 72    False
# Name: FIPS, Length: 73, dtype: bool

# %%
df_hierarchy_nodal_add.sample(15)
# Out:
#       FIPS   BA      nercr      transreg cendiv  st interconnect country  \
# 5   p04012  p28  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 0   p04005  p28  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 10  p04015  p27  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 65  p06073  p11    WECC_CA         CAISO     PA  CA      western     USA
# 37  p06037  p10    WECC_CA         CAISO     PA  CA      western     USA
# 59  p06071  p10    WECC_CA         CAISO     PA  CA      western     USA
# 40  p06065  p10    WECC_CA         CAISO     PA  CA      western     USA
# 63  p06071  p10    WECC_CA         CAISO     PA  CA      western     USA
# 20  p04015  p27  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 58  p06071  p10    WECC_CA         CAISO     PA  CA      western     USA
# 3   p04012  p28  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 69  p32003  p13  WECC_NWPP  NorthernGrid    MTN  NV      western     USA
# 42  p06065  p10    WECC_CA         CAISO     PA  CA      western     USA
# 8   p04012  p28  WECC_SRSG   WestConnect    MTN  AZ      western     USA
# 22  p04015  p27  WECC_SRSG   WestConnect    MTN  AZ      western     USA
#
#         usda      aggreg     county_name Nodal_Zone
# 5   mountain          AZ          La Paz       b106
# 0   mountain          AZ        Coconino       b207
# 10  mountain          AZ          Mohave       b107
# 65   pacific  CA_S_CAISO       San Diego       b122
# 37   pacific  CA_S_CAISO     Los Angeles       b312
# 59   pacific  CA_S_CAISO  San Bernardino       b319
# 40   pacific  CA_S_CAISO       Riverside       b114
# 63   pacific  CA_S_CAISO  San Bernardino       b323
# 20  mountain          AZ          Mohave       b212
# 58   pacific  CA_S_CAISO  San Bernardino       b318
# 3   mountain          AZ          La Paz       b104
# 69  mountain          NV           Clark       b216
# 42   pacific  CA_S_CAISO       Riverside       b116
# 8   mountain          AZ          La Paz       b111
# 22  mountain          AZ          Mohave       b224

# %%
df_hierarchy_nodal_add = df_hierarchy_nodal_add.reindex(columns=['Nodal', 'FIPS', 'BA', 'nercr', 'transreg', 'st', 'interconnect', 'country', 'usda', 'aggreg', 'county_name'])

# %%
df_hierarchy_nodal_add
# Out:
#    Nodal_Zone    FIPS   BA      nercr      transreg  st interconnect country  \
# 0        b207  p04005  p28  WECC_SRSG   WestConnect  AZ      western     USA
# 1        b208  p04005  p28  WECC_SRSG   WestConnect  AZ      western     USA
# 2        b101  p04012  p28  WECC_SRSG   WestConnect  AZ      western     USA
# 3        b104  p04012  p28  WECC_SRSG   WestConnect  AZ      western     USA
# 4        b105  p04012  p28  WECC_SRSG   WestConnect  AZ      western     USA
# ..        ...     ...  ...        ...           ...  ..          ...     ...
# 68       b215  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
# 69       b216  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
# 70       b219  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
# 71       b222  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
# 72       b223  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
#
#         usda aggreg county_name
# 0   mountain     AZ    Coconino
# 1   mountain     AZ    Coconino
# 2   mountain     AZ      La Paz
# 3   mountain     AZ      La Paz
# 4   mountain     AZ      La Paz
# ..       ...    ...         ...
# 68  mountain     NV       Clark
# 69  mountain     NV       Clark
# 70  mountain     NV       Clark
# 71  mountain     NV       Clark
# 72  mountain     NV       Clark
#
# [73 rows x 11 columns]

# %%
df_hierarchy_nodal_add.rename(columns = {'Nodal':'*Nodal'}, inplace = True)
df_hierarchy_nodal_add
# Out:
#    *Nodal_Zone    FIPS   BA      nercr      transreg  st interconnect country  \
# 0         b207  p04005  p28  WECC_SRSG   WestConnect  AZ      western     USA
# 1         b208  p04005  p28  WECC_SRSG   WestConnect  AZ      western     USA
# 2         b101  p04012  p28  WECC_SRSG   WestConnect  AZ      western     USA
# 3         b104  p04012  p28  WECC_SRSG   WestConnect  AZ      western     USA
# 4         b105  p04012  p28  WECC_SRSG   WestConnect  AZ      western     USA
# ..         ...     ...  ...        ...           ...  ..          ...     ...
# 68        b215  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
# 69        b216  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
# 70        b219  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
# 71        b222  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
# 72        b223  p32003  p13  WECC_NWPP  NorthernGrid  NV      western     USA
#
#         usda aggreg county_name
# 0   mountain     AZ    Coconino
# 1   mountain     AZ    Coconino
# 2   mountain     AZ      La Paz
# 3   mountain     AZ      La Paz
# 4   mountain     AZ      La Paz
# ..       ...    ...         ...
# 68  mountain     NV       Clark
# 69  mountain     NV       Clark
# 70  mountain     NV       Clark
# 71  mountain     NV       Clark
# 72  mountain     NV       Clark
#
# [73 rows x 11 columns]

# %%
# Write dataframe to csv file (UNCOMPRESSED)
df_hierarchy_nodal_add.to_csv('C:\\Users\\akarmaka\\Documents\\GitHub\\ReEDS-2.0\\inputs\\hierarchy_rts_nodal.csv', sep=',', encoding='utf-8', index=False)
